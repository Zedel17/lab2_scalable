# %% [markdown]
# ## Model Comparison: Base vs Fine-Tuned vs Customer-Specialized Llama-3.2-1B
#
# This notebook is designed to evaluate and compare the performance of three versions of the Llama-3.2-1B model:
#
# 1. **Base Model**: The original Llama-3.2-1B-Instruct model from Meta, providing a general-purpose language understanding and generation baseline.
# 2. **Fine-Tuned Model**: A version fine-tuned on the FineTome-100k dataset to improve instruction following, response coherence, and task-specific performance.
# 3. **Customer Support Fine-Tuned Model**: A specialized model trained on the Bitext Customer Support dataset, optimized to handle customer queries professionally and contextually.
#
# The goal of this notebook is to demonstrate the improvements introduced by fine-tuning and to highlight the benefits of domain-specific adaptation.
#
# We'll run a set of structured prompts covering general conversation, instructions, knowledge questions, problem-solving, code-related queries, creative tasks, and customer support scenarios. The outputs of all three models will be displayed side by side for direct comparison.

# %% [markdown]
# ## 1. Setup and Installation

# %%
# Install required packages
install_packages = True

if install_packages:
    # !pip install -q -U transformers accelerate peft bitsandbytes
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 2.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 151.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.4/59.4 MB 14.3 MB/s eta 0:00:00

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig
import warnings
warnings.filterwarnings('ignore')

print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"CUDA device: {torch.cuda.get_device_name(0)}")
# Out:
# PyTorch version: 2.9.0+cu126
# CUDA available: True
# CUDA device: Tesla T4

# %% [markdown]
# ## 2. Load Models
#
# We'll load:
# - Base Llama-3.2-1B-Instruct model
# - Fine-tuned model with LoRA adapters from HuggingFace Hub

# %%
import os

# Load HuggingFace token securely
# Priority: Colab secrets > Environment variable > .env file
try:
    from google.colab import userdata
    hf_token = userdata.get('HF_TOKEN')
    print("✓ Loaded token from Colab secrets")
except:
    hf_token = os.environ.get('HF_TOKEN')
    if hf_token:
        print("✓ Loaded token from environment variable")
    else:
        # Try loading from .env file
        try:
            env_path = '../.env'
            if os.path.exists(env_path):
                with open(env_path, 'r') as f:
                    for line in f:
                        if line.strip().startswith('HF_TOKEN='):
                            hf_token = line.strip().split('=', 1)[1]
                            print("✓ Loaded token from .env file")
                            break
        except:
            pass

if not hf_token:
    print("⚠️  WARNING: HF_TOKEN not found!")
    print("Please add it to Colab secrets or set HF_TOKEN environment variable")
    print("Get your token from: https://huggingface.co/settings/tokens")

# %%
# HuggingFace token (if models are private)
from huggingface_hub import login

# Set to False if already logged in
do_login = True

if do_login:
    hf_token = hf_token  # Replace with your token
    login(token=hf_token)

# %%
# Load base model
print("Loading base model...")
base_model_id = "meta-llama/Llama-3.2-1B-Instruct"

# Configure 4-bit quantization
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.bfloat16
)

base_model = AutoModelForCausalLM.from_pretrained(
    base_model_id,
    quantization_config=bnb_config,
    device_map="auto",
)

tokenizer = AutoTokenizer.from_pretrained(base_model_id)
tokenizer.pad_token = tokenizer.eos_token

print("Base model loaded successfully!")
# Out:
# Loading base model...
# config.json:   0%|          | 0.00/877 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.47G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/189 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/54.5k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/296 [00:00<?, ?B/s]
# Base model loaded successfully!

# %%
# Load fine-tuned model with LoRA adapters
from peft import PeftModel

print("Loading fine-tuned model with LoRA adapters...")

# Load LoRA adapters from HuggingFace Hub
finetuned_model_repo = "Zedel17/fine_tuned_llama_1b"  # Your HF repo with LoRA adapters

# Configure 4-bit quantization (same as base model)
bnb_config_ft = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.bfloat16
)

# Create base model for fine-tuned version
finetuned_base = AutoModelForCausalLM.from_pretrained(
    base_model_id,
    quantization_config=bnb_config_ft,
    device_map="auto",
)

# Load LoRA adapters on top
finetuned_model = PeftModel.from_pretrained(
    finetuned_base,
    finetuned_model_repo,
)

print("Fine-tuned model loaded successfully!")
# Out:
# Loading fine-tuned model with LoRA adapters...
# adapter_config.json: 0.00B [00:00, ?B/s]
# adapter_model.safetensors:   0%|          | 0.00/22.6M [00:00<?, ?B/s]
# Fine-tuned model loaded successfully!

# %%
# Load Customer Support fine-tuned model
from peft import PeftModel

print("Loading customer support fine-tuned model...")

customer_model_repo = "Zedel17/fine_tuned_llama_1b_Customer"  # HF repo con LoRA adapters

# Base model for customer support (4-bit quantization)
customer_base = AutoModelForCausalLM.from_pretrained(
    base_model_id,
    quantization_config=bnb_config,  # puoi riusare la stessa config del base
    device_map="auto",
)

# Load LoRA adapters
customer_model = PeftModel.from_pretrained(
    customer_base,
    customer_model_repo,
)

print("Customer support fine-tuned model loaded successfully!")
# Out:
# Loading customer support fine-tuned model...
# adapter_config.json: 0.00B [00:00, ?B/s]
# adapter_model.safetensors:   0%|          | 0.00/22.6M [00:00<?, ?B/s]
# Customer support fine-tuned model loaded successfully!

# %% [markdown]
# ## 3. Inference Helper Functions

# %%
def generate_response(model, tokenizer, prompt, max_new_tokens=256, temperature=0.7):
    """
    Generate response from model using chat template.

    Args:
        model: The model to use for generation
        tokenizer: The tokenizer
        prompt: User prompt string
        max_new_tokens: Maximum tokens to generate
        temperature: Sampling temperature

    Returns:
        Generated response string
    """
    # Format using Llama-3 chat template
    messages = [
        {"role": "user", "content": prompt}
    ]

    # Apply chat template
    formatted_prompt = tokenizer.apply_chat_template(
        messages,
        tokenize=False,
        add_generation_prompt=True
    )

    # Tokenize
    inputs = tokenizer(formatted_prompt, return_tensors="pt").to(model.device)

    # Generate
    with torch.no_grad():
        outputs = model.generate(
            **inputs,
            max_new_tokens=max_new_tokens,
            temperature=temperature,
            top_p=0.9,
            do_sample=True,
            pad_token_id=tokenizer.eos_token_id,
            eos_token_id=tokenizer.eos_token_id,
        )

    # Decode only the new tokens (exclude input prompt)
    response = tokenizer.decode(outputs[0][inputs['input_ids'].shape[1]:], skip_special_tokens=True)

    return response.strip()

def compare_models(base_model, finetuned_model, tokenizer, prompt, max_new_tokens=256):
    """
    Compare outputs from base and fine-tuned models.

    Args:
        base_model: Base model
        finetuned_model: Fine-tuned model
        tokenizer: Tokenizer
        prompt: User prompt
        max_new_tokens: Max tokens to generate
    """
    print(f"\n{'='*80}")
    print(f"PROMPT: {prompt}")
    print(f"{'='*80}\n")

    print("\n[BASE MODEL RESPONSE]")
    print("-" * 80)
    base_response = generate_response(base_model, tokenizer, prompt, max_new_tokens)
    print(base_response)

    print("\n[FINE-TUNED MODEL RESPONSE]")
    print("-" * 80)
    finetuned_response = generate_response(finetuned_model, tokenizer, prompt, max_new_tokens)
    print(finetuned_response)

    print("\n" + "="*80 + "\n")

    return base_response, finetuned_response

def compare_multiple_models(models, model_names, tokenizer, prompt, max_new_tokens=256):
    """
    Compare outputs from multiple models.

    Args:
        models: list of models
        model_names: list of model names (strings)
        tokenizer: tokenizer
        prompt: user prompt
        max_new_tokens: max tokens to generate
    """
    print(f"\n{'='*80}")
    print(f"PROMPT: {prompt}")
    print(f"{'='*80}\n")

    responses = {}
    for name, model in zip(model_names, models):
        print(f"[{name.upper()} RESPONSE]")
        print("-" * 80)
        resp = generate_response(model, tokenizer, prompt, max_new_tokens)
        print(resp + "\n")
        responses[name] = resp

    print("="*80 + "\n")
    return responses

# %% [markdown]
# ## 4. Test Prompts and Comparison
#
# We'll test various types of prompts to evaluate model improvements:
# - General conversation
# - Instruction following
# - Knowledge questions
# - Creative tasks
# - Code-related questions

# %% [markdown]
# ### Test 1: General Conversation

# %%
prompt1 = "Hello! How are you today?"
base_resp1, ft_resp1 = compare_models(base_model, finetuned_model, tokenizer, prompt1)
# Out:
# ================================================================================
# PROMPT: Hello! How are you today?
# ================================================================================
#
#
# [BASE MODEL RESPONSE]
# --------------------------------------------------------------------------------
# I'm just a computer program, so I don't have feelings or emotions like humans do, but I'm functioning properly and ready to help with any questions or tasks you may have! How about you? How's your day going so far?
#
# [FINE-TUNED MODEL RESPONSE]
# --------------------------------------------------------------------------------
# I'm just a language model, so I don't have feelings, but I'm functioning properly and ready to help with any questions or tasks you may have. It's great to start the day! How can I assist you today?
#
# ================================================================================

# %% [markdown]
# ### Test 2: Instruction Following

# %%
prompt2 = "Write a short poem about artificial intelligence in 4 lines."
base_resp2, ft_resp2 = compare_models(base_model, finetuned_model, tokenizer, prompt2)
# Out:
# ================================================================================
# PROMPT: Write a short poem about artificial intelligence in 4 lines.
# ================================================================================
#
#
# [BASE MODEL RESPONSE]
# --------------------------------------------------------------------------------
# Here's a short poem about artificial intelligence:
#
# In silicon halls, it reigns supreme,
# A force that's changing humanity's dream.
# With logic and reason, it takes its place,
# A future where machines find a steady pace.
#
# [FINE-TUNED MODEL RESPONSE]
# --------------------------------------------------------------------------------
# Here's a short poem about artificial intelligence:
#
# Artificial intelligence, a future so bright,
# A world of possibilities, a wondrous sight.
# It learns and adapts, with logic so grand,
# Bringing efficiency and innovation to our land.
#
# ================================================================================

# %% [markdown]
# ### Test 3: Knowledge Question

# %%
prompt3 = "Explain the concept of machine learning in simple terms."
base_resp3, ft_resp3 = compare_models(base_model, finetuned_model, tokenizer, prompt3)
# Out:
# ================================================================================
# PROMPT: Explain the concept of machine learning in simple terms.
# ================================================================================
#
#
# [BASE MODEL RESPONSE]
# --------------------------------------------------------------------------------
# Machine learning is a way to create intelligent systems that can learn from data without being explicitly programmed. It's like having a super smart assistant that can analyze patterns and make predictions or decisions without needing a human to tell it what to do.
#
# Imagine you're at a restaurant and you're ordering food. You don't need to tell the waiter what you want to eat; you just tell the waiter what you like (e.g., Italian, spicy, vegan). The waiter knows exactly what to make for you because of your previous orders (you're familiar with the restaurant's menu). This is similar to machine learning – a machine (or computer) is trained on data (the restaurant's menu) and it uses that data to make decisions (like what to order for you).
#
# Machine learning works in the same way. A machine is given a lot of data (like the restaurant's menu) and it's trained on that data to recognize patterns and make predictions or decisions. Here are some simple examples:
#
# 1. Image recognition: Google Photos uses machine learning to recognize objects in pictures.
# 2. Predictive modeling: Insurance companies use machine learning to predict the likelihood of someone having a certain health condition.
# 3. Chatbots: Amazon's Alexa and other virtual assistants use machine learning to understand voice
#
# [FINE-TUNED MODEL RESPONSE]
# --------------------------------------------------------------------------------
# Machine learning is a way for computers to improve their performance on a task by learning from data and making predictions or decisions without being explicitly programmed for every step. Here's a simplified explanation:
#
# **How it works:**
#
# Imagine you want a computer to recognize a cat. A traditional approach would be to:
#
# 1. Train a computer model to recognize the characteristics of a cat (e.g., whiskers, fur texture, size).
# 2. Use the model to classify a new, unseen cat image as either "cat" or "not cat".
# 3. Refine the model by adjusting the characteristics to improve its accuracy.
# 4. Repeat the process for many images, gradually improving the model's accuracy.
#
# Machine learning achieves this by:
#
# 1. Collecting and labeling data (training data)
# 2. Training the model to learn patterns and relationships in the data
# 3. Using algorithms to optimize the model's performance
# 4. Iterating and refining the model until it reaches a high level of accuracy
#
# **Key concepts:**
#
# 1. **Data**: The input to the machine learning algorithm, which is the data it's trained on.
# 2. **Model**: The algorithm itself, which is the machine learning process that learns from the data.
# 3. **Training data**: The initial data used
#
# ================================================================================

# %% [markdown]
# ### Test 4: Problem Solving

# %%
prompt4 = "Give me 3 tips for staying productive while working from home."
base_resp4, ft_resp4 = compare_models(base_model, finetuned_model, tokenizer, prompt4)
# Out:
# ================================================================================
# PROMPT: Give me 3 tips for staying productive while working from home.
# ================================================================================
#
#
# [BASE MODEL RESPONSE]
# --------------------------------------------------------------------------------
# Here are three tips for staying productive while working from home:
#
# 1. **Create a dedicated workspace**: Designate a specific area for work and keep it organized and clutter-free. This will help you establish a clear boundary between work and personal life. Make sure it's well-lit, comfortable, and equipped with all the necessary tools and equipment.
#
# 2. **Establish a routine and set boundaries with family and friends**: Working from home can be easy to fall into the trap of procrastination or distractions. Create a schedule and stick to it. Set aside specific times for work, breaks, and personal time. Communicate your work hours and boundaries with family and friends to avoid interruptions.
#
# 3. **Take breaks and exercise regularly**: Working from home can be isolating, which can lead to burnout. Make sure to take breaks and engage in physical activity to maintain your physical and mental well-being. Schedule regular breaks into your day, and try to incorporate some physical activity, such as a short walk or stretching exercises, into your daily routine.
#
# Remember, working from home requires discipline and self-motivation. Staying on track and maintaining a healthy work-life balance will help you stay productive and achieve your goals.
#
# [FINE-TUNED MODEL RESPONSE]
# --------------------------------------------------------------------------------
# Here are 3 tips for staying productive while working from home:
#
# 1. **Create a dedicated workspace**: Designate a specific area of your home as your workspace and keep it organized and clutter-free. This will help you establish a clear boundary between work and personal life, making it easier to focus on your tasks without distractions. Make sure the room is well-lit, comfortable, and equipped with necessary tools and equipment.
#
# 2. **Establish a routine and schedule**: Set a regular schedule for your work hours and stick to it, just as you would in an office setting. This will help you stay focused and avoid procrastination. Set specific work hours, breaks, and time for exercise or social activities. Sticking to a routine will also help you avoid procrastination and stay motivated.
#
# 3. **Minimize distractions and interruptions**: Eliminate or minimize distractions in your workspace, such as turning off notifications on your phone or closing unnecessary tabs on your computer. Consider implementing a "do not disturb" sign or signifying that your workspace is not available for visitors. This will help you stay focused and avoid interruptions from family members, pets, or household chores.
#
# By following these tips, you can stay productive and efficient while working from home, even in a remote setting.
#
# ================================================================================

# %% [markdown]
# ### Test 5: Code-Related Question

# %%
prompt5 = "What is the difference between a list and a tuple in Python?"
base_resp5, ft_resp5 = compare_models(base_model, finetuned_model, tokenizer, prompt5)
# Out:
# ================================================================================
# PROMPT: What is the difference between a list and a tuple in Python?
# ================================================================================
#
#
# [BASE MODEL RESPONSE]
# --------------------------------------------------------------------------------
# In Python, both lists and tuples are data structures that are used to store collections of items, but they have some key differences:
#
# **Lists vs Tuples:**
#
# 1. **Immutability**: Lists are mutable, meaning they can be changed after creation. Tuples are immutable, meaning their contents cannot be modified after creation.
# 2. **Indexing**: Lists allow for indexing, which means you can access individual elements using their index. Tuples do not support indexing.
# 3. **Methods**: Lists have methods like `append`, `insert`, `remove`, etc. that allow you to modify the list. Tuples do not have these methods.
# 4. **Length**: Lists are dynamic, meaning their length can be changed. Tuples are fixed, meaning their length is fixed.
# 5. **Initialization**: Lists can be initialized with a list literal, while tuples are initialized with a tuple literal.
#
# **Example:**
#
# ```python
# # Lists
# my_list = [1, 2, 3, 4, 5]
# print(my_list)  # Output: [1, 2, 3, 4, 5]
#
# # Tuples
# my_tuple = (1, 2, 3, 4, 5)
# print(my
#
# [FINE-TUNED MODEL RESPONSE]
# --------------------------------------------------------------------------------
# In Python, a list and a tuple are two fundamental data structures used for storing collections of items. The main difference between them is their purpose, data type, and usage.
#
# **List:**
#
# - A list is a dynamic, mutable, and ordered collection of items that can be of any data type, including strings, integers, floats, and other lists.
# - Lists are defined using square brackets `[]` and are typically used for storing a collection of items that need to be accessed and modified.
# - Lists are mutable, meaning their contents can be changed after creation.
# - Lists are denoted by `[]` and are the most commonly used data structure in Python.
#
# **Tuple:**
#
# - A tuple is a fixed-size, immutable, and ordered collection of items that can be of any data type.
# - Tuples are defined using parentheses `()` and are typically used for storing a collection of items that need to be accessed and not modified.
# - Tuples are denoted by `()` and are the second most commonly used data structure in Python.
#
# **Key differences:**
#
# - **Mutability:** Lists are mutable, while tuples are immutable.
# - **Accessibility:** Lists can be accessed and modified directly, while tuples are accessed using index-based indexing.
# - **Size:**
#
# ================================================================================

# %% [markdown]
# ### Test 6: Creative Task

# %%
prompt6 = "Suggest a creative name for a coffee shop that specializes in sustainable practices."
base_resp6, ft_resp6 = compare_models(base_model, finetuned_model, tokenizer, prompt6)
# Out:
# ================================================================================
# PROMPT: Suggest a creative name for a coffee shop that specializes in sustainable practices.
# ================================================================================
#
#
# [BASE MODEL RESPONSE]
# --------------------------------------------------------------------------------
# Here are some creative name suggestions for a coffee shop that specializes in sustainable practices:
#
# 1. **Brew & Bloom**: This name suggests growth, harmony, and sustainability, which aligns perfectly with your coffee shop's mission.
# 2. **Green Cup**: This name is simple and straightforward, conveying the eco-friendly aspect of your coffee shop.
# 3. **Earthly Grounds**: This name combines the idea of the earth with the coffee shop's focus on sustainable practices.
# 4. **The Sustainable Bean**: This name highlights the importance of sustainable coffee production and serving.
# 5. **Latté & Leaf**: This name incorporates a playful, earthy element (leaf) while emphasizing the coffee aspect of your shop.
# 6. **Roasted with Care**: This name conveys the attention to detail and care that goes into sourcing sustainable coffee beans.
# 7. **Bean Scene**: This name has a fun, modern vibe and implies that your coffee shop is a hub for eco-conscious customers.
# 8. **The Green Cup**: This name is catchy and easy to remember, with a clear message about sustainability.
# 9. **Roots & Roast**: This name highlights the connection between the coffee plant and the sustainable practices that go into sourcing and roasting.
# 10. **Harvest &
#
# [FINE-TUNED MODEL RESPONSE]
# --------------------------------------------------------------------------------
# Here are some creative name suggestions for a sustainable coffee shop:
#
# 1. **BrewCycle**: This name plays on the idea of recycling and reusing coffee grounds, promoting a closed-loop system for sustainability.
# 2. **Earthly Grounds**: A simple and earthy name that emphasizes the importance of reducing waste and minimizing environmental impact.
# 3. **Bean Scene**: This name highlights the coffee aspect while also conveying a sense of community and social responsibility.
# 4. **Green Cup**: A straightforward name that conveys the shop's commitment to sustainability and eco-friendliness.
# 5. **Roasted Awakening**: This name suggests a transformation from the raw coffee beans to a vibrant, healthy and sustainable business.
# 6. **The Sustainable Cup**: A simple, modern name that proudly proclaims the shop's commitment to sustainability.
# 7. **Cuppa Earth**: A playful name that combines the idea of coffee with a love for the planet.
# 8. **Bean There, Done That**: A fun, catchy name that pokes fun at the common phrase "been there, done that" while still conveying the shop's focus on sustainability.
# 9. **The Green Bean Co.**: A cute and catchy name that incorporates the idea of sustainable practices while also highlighting the coffee aspect.
# 10.
#
# ================================================================================

# %% [markdown]
# ### Test 7: Reasoning Task

# %%
prompt7 = "If it takes 5 machines 5 minutes to make 5 widgets, how long would it take 100 machines to make 100 widgets?"
base_resp7, ft_resp7 = compare_models(base_model, finetuned_model, tokenizer, prompt7)
# Out:
# ================================================================================
# PROMPT: If it takes 5 machines 5 minutes to make 5 widgets, how long would it take 100 machines to make 100 widgets?
# ================================================================================
#
#
# [BASE MODEL RESPONSE]
# --------------------------------------------------------------------------------
# If it takes 5 machines 5 minutes to make 5 widgets, we can calculate the rate at which the machines work together.
#
# Since the rate is 5 widgets per 5 minutes, we can calculate the rate per minute as follows:
#
# Rate per minute = 5 widgets / 5 minutes = 1 widget per minute
#
# Now, if we have 100 machines working at this rate, we can calculate the time it takes to make 100 widgets as follows:
#
# Time = Total widgets / Rate per minute
# = 100 widgets / 1 widget per minute
# = 100 minutes
#
# Therefore, it would take 100 machines 100 minutes to make 100 widgets.
#
# [FINE-TUNED MODEL RESPONSE]
# --------------------------------------------------------------------------------
# To determine the time it would take for 100 machines to make 100 widgets, we can use the concept of work done and the formula:
#
# Work = Rate x Time
#
# Since it takes 5 machines 5 minutes to make 5 widgets, we can calculate the rate of work per machine as:
#
# Rate = 5 widgets / 5 minutes = 1 widget per minute per machine
#
# Now, if we have 100 machines working for the same amount of time, the total work would be 100 widgets.
#
# Time = Work / Rate
# Time = 100 widgets / 1 widget per minute per machine
# Time = 100 minutes
#
# Therefore, it would take 100 machines 100 minutes to make 100 widgets.
#
# ================================================================================

# %% [markdown]
# ##Customer Support

# %%
models = [base_model, finetuned_model, customer_model]
model_names = ["base", "finetuned_finetome", "customer_support"]

prompt = "I'm very disappointed that my issue hasn't been resolved yet. Can you escalate it?"
responses = compare_multiple_models(models, model_names, tokenizer, prompt)
# Out:
# ================================================================================
# PROMPT: I'm very disappointed that my issue hasn't been resolved yet. Can you escalate it?
# ================================================================================
#
# [BASE RESPONSE]
# --------------------------------------------------------------------------------
# I'm so sorry to hear that your issue isn't being resolved yet. I'm here to help and support you in any way I can. While I can't actually escalate your issue to a human representative, I can offer some suggestions to help you further or find a resolution.
#
# Here are a few options:
#
# 1. **Try a different platform or customer support channel**: If you're using a different platform or customer support channel, it's possible that the issue is being handled by someone else. Try reaching out to them directly and see if they can assist you.
# 2. **Contact the company's customer support email or phone number**: If you're unable to reach a customer support representative, you can try contacting the company's customer support email or phone number. This can help you get a human representative's attention to your issue.
# 3. **Escalate to a supervisor or manager**: If you're unable to get help from the customer support representative, you can ask to speak with a supervisor or manager. They may be able to provide more detailed guidance or resolve your issue.
# 4. **Reach out to a trusted friend or family member**: Sometimes, having someone you trust by your side can provide additional support and help you get a resolution.
# 5. **Visit a local store
#
# [FINETUNED_FINETOME RESPONSE]
# --------------------------------------------------------------------------------
# I'm here to help, but I need more information about the issue you're experiencing. Could you please provide more context or details about the issue you're facing and what you've already tried to resolve it? This will help me better understand the situation and provide a more effective solution.
#
# If you're experiencing an issue with a specific product, service, or feature, please provide me with as much information as possible, including:
#
# 1. The product or service involved
# 2. Any error messages or error codes you've encountered
# 3. Steps you've taken to try to resolve the issue
# 4. Any relevant details about the outcome or your attempts to resolve it
#
# This will enable me to provide you with a more accurate and helpful response.
#
# [CUSTOMER_SUPPORT RESPONSE]
# --------------------------------------------------------------------------------
# I'm so sorry to hear that you're still experiencing issues. I'm here to help. However, I need to clarify that I'm a large language model, I don't have direct access to your account or the specific issue you're facing. I'm a text-based model, and I don't store any information about your account or identity.
#
# To escalate your issue, I'll need to know more about it. Please provide me with the following information:
#
# 1. The issue you're trying to resolve
# 2. The specific steps you've taken so far
# 3. Any error messages or error codes
# 4. Any relevant context or background
# 5. The desired outcome or resolution
#
# Once I have this information, I'll do my best to help you escalate the issue and find a solution.
#
# ================================================================================

# %%
models = [base_model, finetuned_model, customer_model]
model_names = ["base", "finetuned_finetome", "customer_support"]

prompt = "Hi, I recently purchased your software but I'm having trouble activating it."
responses = compare_multiple_models(models, model_names, tokenizer, prompt)
# Out:
# ================================================================================
# PROMPT: Hi, I recently purchased your software but I'm having trouble activating it.
# ================================================================================
#
# [BASE RESPONSE]
# --------------------------------------------------------------------------------
# I'm happy to help you with any issues you're experiencing with the software. Could you please provide more details about the issue you're facing? Specifically, what software is it, and what exactly is not working as expected? The more information you can provide, the better I'll be able to assist you.
#
# Also, just to confirm, are you using a specific version of the software, and are you using a Windows or macOS device?
#
# [FINETUNED_FINETOME RESPONSE]
# --------------------------------------------------------------------------------
# I'm happy to help you with any issues you're experiencing with the software. Can you please provide me with more details about the issue you're facing? What exactly you're trying to activate, and any error messages or error codes you're seeing? This will help me better understand the problem and provide a more accurate solution.
#
# Additionally, please let me know if you have already purchased the software from our website or a third-party store. This information will help me to provide a more specific guidance.
#
# [CUSTOMER_SUPPORT RESPONSE]
# --------------------------------------------------------------------------------
# I'm happy to help you with your software. Can you please provide me with more details about the software you purchased and the issue you're facing? This will help me better understand the problem and provide a more accurate solution.
#
# Also, please let me know what operating system you're using (e.g. Windows, macOS, Linux) and what version of the software is installed.
#
# ================================================================================

# %%
models = [base_model, finetuned_model, customer_model]
model_names = ["base", "finetuned_finetome", "customer_support"]

prompt = "I'm unable to log in to my account. I keep getting an 'invalid password' error."
responses = compare_multiple_models(models, model_names, tokenizer, prompt)
# Out:
# ================================================================================
# PROMPT: I'm unable to log in to my account. I keep getting an 'invalid password' error.
# ================================================================================
#
# [BASE RESPONSE]
# --------------------------------------------------------------------------------
# I'm here to help you troubleshoot the issue. Let's go through some steps to resolve the 'invalid password' error.
#
# **Troubleshooting steps to resolve 'invalid password' error:**
#
# 1.  **Check the password length**: Ensure your password is 8 characters long. If it's less than 8 characters, you may be prompted to enter a longer password.
#
# 2.  **Verify password complexity**: The password should include uppercase letters, lowercase letters, numbers, and special characters. If your password doesn't meet this requirement, you might need to create a new one.
#
# 3.  **Check for password expiration**: If your account is set to expire after a certain number of days or months, ensure that your password is not set to expire.
#
# 4.  **Clear cookies and cache**: Clearing cookies and cache can sometimes resolve the issue. You can try clearing the cache and cookies in your web browser.
#
# 5.  **Try a password reset**: If none of the above steps work, try resetting your password. This will prompt you to enter your current password to verify it.
#
# 6.  **Check the password manager**: If you use a password manager, make sure it's up-to-date and not causing any issues.
#
# 7.  **Reset
#
# [FINETUNED_FINETOME RESPONSE]
# --------------------------------------------------------------------------------
# To resolve the 'invalid password' error, let's go through some troubleshooting steps to help you regain access to your account.
#
# 1. **Check the password length**: Ensure that your password is at least 8 characters long. The recommended length is at least 8 characters, but it can be up to 64 characters. If your password is too short, it may not be accepted.
#
# 2. **Check the password complexity**: Make sure your password includes uppercase letters, lowercase letters, numbers, and special characters. This can be achieved by using a combination of uppercase letters, lowercase letters, numbers, and special characters.
#
# 3. **Check for typos or misspellings**: If you've entered your password incorrectly, it might be a typo or misspelling. Double-check that you've entered your password correctly.
#
# 4. **Check your username**: Ensure that your username matches the one you used when you created your account. If you've changed your username, you might need to reset your password.
#
# 5. **Reset your password**: You can reset your password by clicking on the 'Forgot password' link on the login page. Follow the prompts to enter your username and verify your identity.
#
# 6. **Check for account restrictions**: If you've been banned or have a temporary
#
# [CUSTOMER_SUPPORT RESPONSE]
# --------------------------------------------------------------------------------
# If you're having trouble logging in to your account, it's likely due to a weak or forgotten password. Here are some steps you can take to resolve the issue:
#
# 1. **Check your password**: Ensure that you're using the correct password. If you've changed your password recently, it's possible that the old password is still stored in your database. Try using the same password or a variation of it.
# 2. **Check for password reset**: If you've forgotten your password, you might be able to reset it using the 'Forgot Password' option. Check the 'Forgot Password' section on the login page and follow the instructions to reset your password.
# 3. **Check for account lockout**: If you're having trouble logging in, it's possible that your account has been locked out due to too many failed login attempts. Check your account settings to see if there are any restrictions or lockout policies in place.
# 4. **Check for security questions**: If you've set security questions, try answering them to reset your password. If you don't have any security questions, you can try resetting your password using the 'Forgot Password' option.
# 5. **Clear your cookies and cache**: Clearing your cookies and cache can sometimes resolve the issue. To do this
#
# ================================================================================

# %%
models = [base_model, finetuned_model, customer_model]
model_names = ["base", "finetuned_finetome", "customer_support"]

prompt = "I want to return a pair of shoes that don't fit. What is the procedure?"
responses = compare_multiple_models(models, model_names, tokenizer, prompt)
# Out:
# ================================================================================
# PROMPT: I want to return a pair of shoes that don't fit. What is the procedure?
# ================================================================================
#
# [BASE RESPONSE]
# --------------------------------------------------------------------------------
# If you're looking to return a pair of shoes that don't fit, here's a step-by-step guide to help you through the process:
#
# **Before Returning:**
#
# 1. **Check the return policy**: Verify the return policy of the retailer or store where you purchased the shoes. Some stores may have specific requirements, such as a certain time frame or a certain condition for returns.
# 2. **Check the size and fit**: Before returning the shoes, ensure they are not too tight or too loose. If the shoes are too tight, they may be difficult to return or may not fit properly when returned.
#
# **Returning the Shoes:**
#
# 1. **Contact the retailer or store**: Reach out to the retailer or store where you purchased the shoes and explain your situation. They may ask you to contact their customer service department or a specific representative.
# 2. **Provide proof of purchase**: Send a photo of the receipt or proof of purchase with the shoes to prove that you bought the shoes.
# 3. **Fill out the return form**: The retailer or store will provide a return form or ask you to fill one out. This form should include your name, contact information, and the reason for the return.
# 4. **Include the shoes**: Make sure to include the shoes in the
#
# [FINETUNED_FINETOME RESPONSE]
# --------------------------------------------------------------------------------
# If you want to return a pair of shoes that don't fit, the procedure varies depending on the store or retailer you're purchasing from. Here's a general outline of the steps you can follow:
#
# 1. **Check the return policy**: Before returning the shoes, check the store's return policy to see if they have a specific time frame, conditions, and any restocking fees.
#
# 2. **Contact the store**: Reach out to the store via phone, email, or in-store to initiate the return process. Provide your order number, the reason for return, and your contact information.
#
# 3. **Fill out the return form**: The store will provide you with a return form. Fill it out with your order details, including the product name, size, and the reason for return.
#
# 4. **Provide the required documents**: The store may request additional documents, such as your receipt, a photo of the shoes, or a proof of purchase.
#
# 5. **Return the shoes**: Hand over the shoes to the store, usually in the same condition as when you received them. If the shoes are in a different condition, you may be asked to pay for any damage or wear.
#
# 6. **Get a refund**: The store will process the return and issue a refund or provide
#
# [CUSTOMER_SUPPORT RESPONSE]
# --------------------------------------------------------------------------------
# If you want to return a pair of shoes that don't fit, here's a step-by-step procedure:
#
# **Before returning:**
# 1. Check the return policy: Before returning the shoes, check the return policy of the store or online retailer. They may have specific conditions, such as a restocking fee, minimum purchase, or a certain period for returns.
# 2. Gather required documents: You may need to provide proof of purchase, such as a receipt or the original box and tags.
# 3. Call the store: If you're still unsure, give the store a call to confirm their return policy and the required documents.
#
# **Returning the shoes:**
# 1. Go to the store: If the store is still open, go there and ask to return the shoes.
# 2. Inform the staff: Let the staff know that you want to return the shoes, and they will ask you for the required documents.
# 3. Provide the documents: Hand over the documents to the staff, and they will check them to ensure they're in order.
# 4. Ask for a return: The staff will ask you to sign a return slip, which will be provided to you.
# 5. Receive a return: The staff will then process the return and hand over the shoes, or they'll
#
# ================================================================================

# %%
models = [base_model, finetuned_model, customer_model]
model_names = ["base", "finetuned_finetome", "customer_support"]

prompt = "Are there any discounts on electronics this weekend?"
responses = compare_multiple_models(models, model_names, tokenizer, prompt)
# Out:
# ================================================================================
# PROMPT: Are there any discounts on electronics this weekend?
# ================================================================================
#
# [BASE RESPONSE]
# --------------------------------------------------------------------------------
# I'm happy to help you find deals on electronics. However, I'm a large language model, I don't have real-time access to current deals and discounts. But I can suggest some options to help you find deals:
#
# 1. **Manufacturer's websites**: Check the official websites of your favorite electronics brands for any sale or promotion. They often offer discounts on various products.
# 2. **Online Retailers**: Websites like Amazon, Best Buy, and Newegg often have deals and discounts on electronics. You can check their websites for any available discounts.
# 3. **Deal Websites**: Websites like Slickdeals, RetailMeNot, and Coupons.com aggregate deals and discounts on various products. You can search for "electronics deals" or specific products to find what's on sale.
# 4. **Deal Alerts**: Sign up for deal alert services like RetailMeNot, Coupons.com, or Slickdeals to receive notifications about upcoming sales and discounts.
# 5. **Manufacturer's Social Media**: Follow your favorite electronics brands on social media platforms like Facebook, Twitter, or Instagram. They often post about sales and promotions.
# 6. **Discount Stores**: Visit discount stores like Best Buy Outlet, Fry's Electronics, or Micro Center, which often have discounted prices on electronics.
# 7. **
#
# [FINETUNED_FINETOME RESPONSE]
# --------------------------------------------------------------------------------
# To get the most accurate and up-to-date information on discounts, I recommend checking the following sources:
#
# 1. Online Retailers:
#    - Amazon (amazon.com)
#    - Best Buy (bestbuy.com)
#    - Walmart (walmart.com)
#    - Target (target.com)
#    - eBay (ebay.com)
#
# 2. Retail Stores:
#    - Check the websites of electronics stores in your area for any promotions or discounts.
#
# 3. Manufacturer's Websites:
#    - Check the websites of your favorite electronics brands for any discounts or promotions.
#
# 4. Sign up for newsletters or follow social media accounts of retailers to stay informed about their deals and discounts.
#
# 5. Look for deals and discounts on websites like RetailMeNot, Coupons.com, or CouponCabin.
#
# Some popular electronics deals this weekend include:
# - 4K TVs and laptops with discounts on Samsung, LG, and Sony
# - Gaming consoles like PlayStation and Xbox with discounts on bundles
# - Smartphones and tablets with discounts on Apple, Samsung, and Google
# - Home audio equipment and speakers with discounts on Amazon and Best Buy
#
# Please note that deals can change quickly, so it's essential to verify the discounts and prices before making a purchase.
#
# [CUSTOMER_SUPPORT RESPONSE]
# --------------------------------------------------------------------------------
# I'm not aware of any specific discounts on electronics for this weekend. However, I can suggest a few options to help you find the best deals:
#
# 1. Check online marketplaces: Websites like Amazon, Newegg, and Best Buy often offer discounts and promo codes for various electronics. You can check their websites for any available deals.
# 2. Look for local retailers: Visit local electronics stores or big-box stores like Best Buy, Walmart, or Target. They might have in-store deals or discounts that aren't available online.
# 3. Sign up for newsletters: Sign up for newsletters from your favorite electronics retailers, and they'll send you exclusive offers and discounts.
# 4. Follow social media: Follow your favorite electronics brands and retailers on social media. They often post about upcoming deals and discounts.
# 5. Check for holiday sales: Many retailers offer holiday sales, like Black Friday, Cyber Monday, and Memorial Day. These sales can be a great time to find discounts on electronics.
# 6. Use price comparison tools: Websites like PriceGrabber or PriceRunner can help you compare prices and find the best deals on electronics.
#
# Some popular electronics deals this weekend include:
#
# * 4K TV: 20-30% off at Best Buy, Walmart, or Amazon
# * Smartphones:
#
# ================================================================================

# %%
models = [base_model, finetuned_model, customer_model]
model_names = ["base", "finetuned_finetome", "customer_support"]

prompt = "I tried to pay with my credit card, but the payment didn't go through."
responses = compare_multiple_models(models, model_names, tokenizer, prompt)
# Out:
# ================================================================================
# PROMPT: I tried to pay with my credit card, but the payment didn't go through.
# ================================================================================
#
# [BASE RESPONSE]
# --------------------------------------------------------------------------------
# If you tried to pay with your credit card and the payment didn't go through, here are some steps you can take to resolve the issue:
#
# 1. **Check your card details**: Double-check that your card details are correct, including the card number, expiration date, and security code. Make sure you're using the correct card for the payment.
# 2. **Check your payment method**: Ensure you're using the correct payment method, such as credit card, PayPal, or another payment method accepted by the merchant.
# 3. **Verify the payment gateway**: Check if the payment gateway is working correctly. You can try logging out of your account and clearing your cookies to clear any temporary issues.
# 4. **Check for any transaction history**: Check your transaction history to ensure there are no pending or rejected transactions. If you're using a mobile app, check the app's transaction history.
# 5. **Contact the merchant's customer service**: Reach out to the merchant's customer service department via phone, email, or live chat to report the issue. They should be able to assist you with resolving the payment issue.
# 6. **Check for any technical issues**: Ensure your internet connection and browser are working properly. You can try restarting your browser or checking for any pop-ups or ads that might
#
# [FINETUNED_FINETOME RESPONSE]
# --------------------------------------------------------------------------------
# If you're trying to pay with a credit card and it didn't go through, here are some steps you can take:
#
# 1. **Contact the merchant's customer service**: Reach out to the store or merchant's customer service department via phone, email, or live chat. Explain the situation and provide your credit card information. They may be able to help resolve the issue or provide additional guidance.
#
# 2. **Check your transaction history**: Review your credit card statement to see if the payment was made and if it was successful. Sometimes, issues can arise when the payment was processed but not confirmed.
#
# 3. **Check for any errors or disputes**: If you're disputing the charge, review the transaction details and contact the merchant's customer service to resolve the issue. They may need to review the transaction and provide a refund or explanation for the disputed amount.
#
# 4. **Check your credit card's billing cycle**: Ensure that the credit card is not expiring soon. If it is expiring soon, you might need to renew it or set up a payment plan to avoid any potential issues.
#
# 5. **Verify your payment method**: Double-check that your payment method is enabled for online purchases. If not, you may need to enable it or set up a separate payment method.
#
# 6
#
# [CUSTOMER_SUPPORT RESPONSE]
# --------------------------------------------------------------------------------
# If the payment didn't go through, here are some steps you can try to resolve the issue:
#
# 1. **Check the payment method**: Ensure that your credit card is in good standing and not expired. Also, verify that the card has not been frozen or declined.
# 2. **Check the payment date**: If your payment is due, try paying earlier in the day to avoid late fees. Some merchants might have a 24-hour window for early payment.
# 3. **Check the payment method again**: Double-check the payment details, including the card number, expiration date, and security code.
# 4. **Contact the merchant**: Reach out to the merchant's customer service or contact their 24-hour hotline to report the issue. They may be able to help you resolve the problem.
# 5. **Check for any errors**: Verify that there are no errors in the transaction, such as invalid payment methods or incorrect payment dates.
# 6. **Check for any payment restrictions**: If you're a student, senior, or have a disability, check if there are any restrictions on your credit card that might be causing the issue.
# 7. **Check your credit card agreement**: Review your credit card agreement to see if there are any specific requirements or restrictions for making payments.
# 8. **Contact
#
# ================================================================================

# %% [markdown]
# ## 5. Analysis and Conclusions
#
# ### Expected Improvements from Fine-Tuning:
#
# 1. **Better Instruction Following**: The fine-tuned model should better understand and follow specific instructions, as it was trained on the FineTome-100k dataset which contains high-quality instruction-response pairs.
#
# 2. **More Coherent Responses**: Fine-tuning on conversational data should result in more natural, coherent responses that stay on topic.
#
# 3. **Improved Format Adherence**: The model should better respect the chat format and provide responses that are appropriately structured.
#
# 4. **Enhanced Task Completion**: For specific tasks (writing poems, answering questions, etc.), the fine-tuned model should provide more complete and relevant responses.
#
# ### Customer-service prompts:
#
# The base model responded with generic troubleshooting steps, coherent but not specifically aligned to customer-support workflows.
# The Finetone fine-tuned model showed better structure and prioritised merchant-contact actions, reflecting the patterns present in the training data.
# The Bitext-trained model produced a longer list of checks and policies, but also displayed redundancy and occasional irrelevant items (e.g., special‐category restrictions), which mirrors the somewhat noisy and heterogeneous nature of the Bitext dataset.
#
# None of the three models fully completed their response. This behaviour is consistent with small-scale models (1B parameters), which often stop early when producing enumerations or longer explanations. It is also amplified when training datasets contain incomplete examples or when the generation budget is insufficient.
#
# ### Conclusion:
#
# The fine-tuned Llama-3.2-1B model demonstrates improvements over the base model. The LoRA fine-tuning approach successfully adapted the model to the FineTome-100k dataset while maintaining efficiency through parameter-efficient training.
